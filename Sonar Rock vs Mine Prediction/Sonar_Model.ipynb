# %%
import joblib #importing joblib for model serialization

# %%
MJ = joblib.load('sonar_model.sav')  #loading the saved model from file

# %%
prediction = MJ.predict([[
    0.0115, 0.015, 0.0136, 0.0076, 0.0211, 0.1058, 0.1023, 0.044, 0.0931, 0.0734,
    0.074, 0.0622, 0.1055, 0.1183, 0.1721, 0.2584, 0.3232, 0.3817, 0.4243, 0.4217,
    0.4449, 0.4075, 0.3306, 0.4012, 0.4466, 0.5218, 0.7552, 0.9503, 1.0, 0.9084,
    0.8283, 0.7571, 0.7262, 0.6152, 0.568, 0.5757, 0.5324, 0.3672, 0.1669, 0.0866,
    0.0646, 0.1891, 0.2683, 0.2887, 0.2341, 0.1668, 0.1015, 0.1195, 0.0704, 0.0167,
    0.0107, 0.0091, 0.0016, 0.0084, 0.0064, 0.0026, 0.0029, 0.0037, 0.007, 0.0041
]])

if (prediction[0] == 'R'):
    print('The object is a Rock')   #if prediction is 'R', it's a Rock
else:
    print('The object is a Mine')   #if prediction is 'M', it's a Mine
# Out:
# The object is a Rock
